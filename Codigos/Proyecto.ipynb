# %% [markdown]
# Antes de ejecutarlo tienes que asegurarte de que el archivo location.py está en la misma carpeta que el jupyter

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/Shareddrives/Codigos
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/content/drive/Shareddrives/Codigos'
# /content

# %%
import location
from bs4 import BeautifulSoup
import requests
import lxml
import re
import pandas as pd
import numpy as np

from ETL_AenaToCSV import getDESTINOS
from WRAPPER_GetPrecio import getPRECIOS
from funciones_capitales import getCapitales, setCapitales 
from mejoresdestinos import MejoresDESTINOS
from funcionpablo import PablitoPlanes
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5f638195883f> in <module>
# ----> 1 import location
#       2 from bs4 import BeautifulSoup
#       3 import requests
#       4 import lxml
#       5 import re
#
# ModuleNotFoundError: No module named 'location'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
mapa = location.driver()
mapa
# Out:
# Me das acceso a tu ubicación: Si o No: Si

# %% [markdown]
# Poneer un par de botones del estilo: ¿A donde quieres ir?
#
# Capitales Europeas ||| Capitales Americanas
#
# Indicar que como es un "proyecto" de momento solo trabajamos con ciudades Europeas. Entonces mostrar este listado bonito

# %%
path_output="/home/vant/Descargas/Codigos-20221207T185544Z-001/Codigos"  #Cambiar cuando se pase a linux.
ReadCapitales=pd.read_csv(path_output+'/CAPITALES_CHINGONAS.csv')
ReadCapitales

# %% [markdown]
# Aqui habrá que correr esta función la cual te busca el vuelo mas barato del mes que viene para todas las capitales. lo suyo seria ofrecer al usuario los 5 destinos más baratos con sus 5 fechas. ESTO HAY QUE PONERLO BONITO... SE PUEDE EJCUTAR DE FORMA OCULTA? sin mostrar codigo
#
# NOTA: Ya se que no se puede elegir el dia que quieres viajar. Para eso hace falta encontrar una api que sea mejor... esta es gratis y yo no encontré otra. Cumple su cometido, nos sirve como una fuente de datos más que hemos integrado (de eso va el proyecto). En el informe esto lo podemos justificar con que era la unica opción gratis y que como esto es una propuesta el tema hace su servicio

# %%
Precios=getPRECIOS(ReadCapitales,"w",path_output)
Precios
# Out:
#     Unnamed: 0                           Destino Aeropuerto  \
# 0            0  BERLIN-BRANDERBURG WILLY BRANDT         BER
# 1            1                  ROMA /FIUMICINO         FCO
# 2            2            PARIS /BEAUVAIS-TILLE         BVA
# 3            3         PARIS /CHARLES DE GAULLE         CDG
# 4            4                      PARIS /ORLY         ORY
# 5            5                         BUCAREST         OTP
# 6            6                            VIENA         VIE
# 7            7                         VARSOVIA         WAW
# 8            8                  VARSOVIA/MODLIN         WMI
# 9            9                         BUDAPEST         BUD
# 10          10                            PRAGA         PRG
# 11          11                            SOFIA         SOF
# 12          12                         BRUSELAS         BRU
# 13          13              BRUSELAS /CHARLEROI         CRL
# 14          14               ESTOCOLMO /ARLANDA         ARN
# ...

# %%
#Obtenemos los 5 destinos mas baratos:
LISTA_5Destinos=MejoresDESTINOS(Precios)
LISTA_5Destinos

# %%
#Obtenemos planes y descripion general del destino
for ciudades in LISTA_5Destinos['Recomendaciones']:
    (a,b,c)=PablitoPlanes(ciudades.replace(' ',''),5)
    print("Ciudad: ",ciudades)
    print(b,"\n")
    print(c,"\n")
    print("Lista de planes: \n")
    print(a,"\n")
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
# Out:
# Ciudad:  LISBOA
# Esplendor europeo poco conocido
#
# Situada en un enclave entre siete colinas, esta ciudad ideal para caminar se erige como una alternativa fascinante a las capitales más populares de Europa. La animada vida nocturna de Lisboa, sus alegres mercados y sus vibrantes museos proporcionan montones de opciones entre las que no pueden faltar unas copas de vino de Oporto, una buena ración de bacalao y pastéis de nata.
#
# Lista de planes:
#
# ['Castillo de San Jorge', 'Miradouro da Senhora do Monte', 'Barrio Alto', 'Praca do Comercio (Terreiro do Paco)', 'Alfama']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ciudad:  BRUSELAS /CHARLEROI
# Acerca de Bruselas
#
# ...
